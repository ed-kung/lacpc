# %%
import os
import sys
import re
import time
import yaml
from pathlib import Path
import pdfplumber
import pytesseract
from pdf2image import convert_from_path
import warnings
import logging
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

with open('../../config.local.yaml', 'r') as f:
    local_config = yaml.safe_load(f)

LOCAL_PATH = local_config['LOCAL_PATH']
TESSERACT = local_config['TESSERACT']

sys.path.append(os.path.join(LOCAL_PATH, "src/python"))
pytesseract.pytesseract.tesseract_cmd = TESSERACT

warnings.filterwarnings('default')
logging.getLogger("pdfminer").setLevel(logging.ERROR)

DATA_DIR = Path(os.path.join(LOCAL_PATH, "raw_data/cpc"))

REPLACE = False  # whether to replace existing txt files

# %%
def extract_text_from_pdf(pdf_path, verbose=True, convert_images=True):
    text_pieces = []
    pages=0
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            pages+=1
            page_text = page.extract_text(x_tolerance=1, layout=True)
            if page_text:
                text_pieces.append(page_text)
            elif convert_images and (page.width/72<17) and (page.height/72<22):
                images = convert_from_path(pdf_path, first_page=i+1, last_page=i+1)
                ocr_text = pytesseract.image_to_string(images[0])
                if ocr_text:
                    text_pieces.append(ocr_text.replace('|','I'))
                else:
                    text_pieces.append('NO TEXT')
            else:
                text_pieces.append('NO TEXT')
            if verbose and (pages%100==0):
                print(f"{pages}... ", end='')
    if verbose:
        print(f"{pages} pages extracted.")
    return "\n<PAGE BREAK>\n".join(text_pieces)

# %%
meta_df = []

t0 = time.time()
years = sorted([d.name for d in DATA_DIR.iterdir() if d.is_dir()])
for year in years:
    year_dir = Path(os.path.join(DATA_DIR, str(year)))
    dates = sorted([d.name for d in year_dir.iterdir() if d.is_dir()])
    for date in dates:
        print(date)
        output_dir = Path(os.path.join(LOCAL_PATH, f"intermediate_data/cpc/{year}/{date}"))
        output_dir.mkdir(parents=True, exist_ok=True)
        pdf_dir = Path(os.path.join(year_dir, date))
        files = [f.name for f in pdf_dir.iterdir()]
        for file in files:
            print(f"  {file}: ", end='')
            filename, ext = file.split('.')
            if ext!='pdf':
                continue
            if os.path.exists(os.path.join(pdf_dir, f"{filename}-override.pdf")):
                pdf_file = os.path.join(pdf_dir, f"{filename}-override.pdf")
            else:
                pdf_file = os.path.join(pdf_dir, f"{filename}.pdf")
            output_file = os.path.join(output_dir, f"{filename}.txt")
            if (not REPLACE) and (os.path.exists(output_file)):
                with open(output_file, 'r', encoding='utf-8') as f:
                    text = f.read()
                print(f"already extracted")
            else:
                text = extract_text_from_pdf(pdf_file)
                with open(output_file, 'w', encoding='utf-8') as f:
                    f.write(text)
            pages = len(text.split("<PAGE BREAK>"))
            meta_df.append({
                'year': year,
                'date': date,
                'filename': filename,
                'pages': pages
            })
t1 = time.time()
print(f"Elapsed time = {(t1-t0)/60} mintues")
# Out:
# 2003-01-09
#   agenda.pdf: already extracted
# 2003-01-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-02-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-02-27
#   agenda.pdf: already extracted
# 2003-03-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-03-27
#   agenda.pdf: already extracted
# 2003-04-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-04-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-05-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-05-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-06-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-06-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-07-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-07-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-08-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-08-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-09-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-09-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-10-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-10-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-11-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-11-20
#   agenda.pdf: already extracted
# 2003-12-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2003-12-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-01-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-01-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-02-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-02-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-03-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-03-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-04-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-04-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-05-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-05-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-06-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-06-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-07-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-07-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-08-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-08-17
#   agenda.pdf: already extracted
# 2004-08-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-09-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-09-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-10-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-10-20
#   agenda.pdf: already extracted
# 2004-10-28
#   agenda.pdf: already extracted
# 2004-11-04
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-11-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-12-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2004-12-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-01-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-01-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-02-10
#   agenda.pdf: already extracted
# 2005-02-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-03-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-03-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-03-31
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-04-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-04-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-05-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-05-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-06-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-06-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-07-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-07-28
#   agenda.pdf: already extracted
# 2005-08-04
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-08-11
#   agenda.pdf: already extracted
# 2005-08-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-08-25
#   agenda.pdf: already extracted
# 2005-09-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-09-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-10-13
#   agenda.pdf: already extracted
# 2005-10-20
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-10-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-11-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-11-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-12-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2005-12-15
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-01-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-01-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2006-02-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2006-02-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-03-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-03-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-03-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-04-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-04-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-05-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-05-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-05-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-06-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-06-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-07-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-07-27
#   agenda.pdf: already extracted
# 2006-08-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-08-21
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-08-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-09-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-09-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-10-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-10-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-11-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-11-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-12-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2006-12-21
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-01-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-01-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-02-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-02-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-03-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-03-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-04-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-04-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-05-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-05-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-06-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-06-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-07-11
#   agenda.pdf: already extracted
# 2007-07-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-07-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-08-03
#   agenda.pdf: already extracted
# 2007-08-15
#   agenda.pdf: already extracted
# 2007-08-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-09-13
#   agenda.pdf: already extracted
# 2007-09-20
#   agenda.pdf: already extracted
# 2007-09-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-10-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-10-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-11-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-11-15
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-12-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2007-12-20
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-01-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-01-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-02-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-02-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-03-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-03-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-04-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-04-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-05-08
#   agenda.pdf: already extracted
# 2008-05-22
#   agenda.pdf: already extracted
# 2008-06-12
#   agenda.pdf: already extracted
# 2008-06-26
#   agenda.pdf: already extracted
# 2008-07-10
#   agenda.pdf: already extracted
# 2008-07-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-08-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-08-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-09-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-09-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-10-09
#   agenda.pdf: already extracted
# 2008-10-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-10-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-11-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-11-20
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-12-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2008-12-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-01-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-01-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-02-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-02-19
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-02-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-03-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-03-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-03-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-04-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-04-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-05-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-05-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-06-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-06-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-07-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-07-23
#   agenda.pdf: already extracted
# 2009-08-11
#   agenda.pdf: already extracted
# 2009-08-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-08-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-09-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-09-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-10-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-10-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-11-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-11-19
#   agenda.pdf: already extracted
# 2009-12-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2009-12-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-01-14
#   agenda.pdf: already extracted
# 2010-01-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-02-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-02-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-03-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-03-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-04-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-04-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-05-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-05-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-06-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-06-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-07-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-07-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-08-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-08-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-09-09
#   agenda.pdf: already extracted
# 2010-09-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-09-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-10-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-10-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-11-04
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-11-11
#   agenda.pdf: already extracted
# 2010-11-18
#   agenda.pdf: already extracted
# 2010-11-25
#   agenda.pdf: already extracted
# 2010-12-02
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-12-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2010-12-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-01-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-01-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-02-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-02-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-03-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-03-24
#   agenda.pdf: already extracted
# 2011-04-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-04-28
#   agenda.pdf: already extracted
# 2011-05-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-05-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-06-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-06-23
#   agenda.pdf: already extracted
# 2011-07-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-07-28
#   agenda.pdf: already extracted
# 2011-08-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-08-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-09-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-09-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-10-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-10-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-11-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-11-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-12-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2011-12-22
#   agenda.pdf: already extracted
# 2012-01-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-01-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-02-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-02-23
#   agenda.pdf: already extracted
# 2012-03-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-03-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-04-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-04-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-05-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-05-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2012-06-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-06-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-07-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-07-26
#   agenda.pdf: already extracted
# 2012-08-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-08-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-09-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-09-14
#   agenda.pdf: already extracted
# 2012-09-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-10-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-10-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-11-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-11-29
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-12-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2012-12-20
#   agenda.pdf: already extracted
# 2013-01-10
#   agenda.pdf: already extracted
# 2013-01-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-02-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-02-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-03-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-03-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-04-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-04-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-05-09
#   agenda.pdf: already extracted
# 2013-05-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-06-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-06-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-07-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2013-07-25
#   agenda.pdf: already extracted
# 2013-08-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-08-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2013-09-12
#   agenda.pdf: already extracted
# 2013-09-26
#   agenda.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-10-10
#   agenda.pdf: already extracted
# 2013-10-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-11-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2013-11-21
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-12-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2013-12-13
#   agenda.pdf: already extracted
# 2013-12-19
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-01-09
#   agenda.pdf: already extracted
# 2014-01-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2014-02-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-02-27
#   agenda.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-03-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-03-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-04-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-04-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-05-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-05-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-06-06
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2014-06-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-06-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-07-10
#   agenda.pdf: already extracted
# 2014-07-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-08-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-08-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-09-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-09-25
#   agenda.pdf: already extracted
# 2014-10-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-10-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-11-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-11-20
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-12-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2014-12-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-01-08
#   agenda.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-01-22
#   agenda.pdf: already extracted
# 2015-02-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-02-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-03-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-03-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-04-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-04-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-05-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-05-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-06-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-06-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-07-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-07-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-08-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-08-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-09-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2015-09-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-10-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-10-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-11-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-11-19
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-12-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2015-12-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
# 2016-01-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-01-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-02-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-02-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-03-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-03-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-04-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-04-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-05-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-05-26
#   agenda.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-06-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-06-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-07-14
#   agenda.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-07-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-08-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-08-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-08-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-09-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-09-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-10-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-10-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-11-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-11-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-12-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2016-12-15
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-01-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-01-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-02-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-02-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-03-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-03-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-04-20
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-04-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-05-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-05-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-06-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-06-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-07-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-07-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-08-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-08-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-09-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-09-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-10-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-10-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-11-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-11-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-12-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2017-12-21
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-01-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-01-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-02-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-02-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-03-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-03-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-04-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-04-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-05-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-05-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-06-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-06-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2018-07-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-07-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-08-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-08-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-09-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-09-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-10-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-10-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-11-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-11-29
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-12-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2018-12-20
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-01-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-01-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-02-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-02-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-03-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-03-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-04-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-04-25
#   agenda.pdf: already extracted
# 2019-05-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-05-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-06-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-06-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-07-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-07-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-08-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-08-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-09-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-09-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-10-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-10-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-11-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-11-21
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-12-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2019-12-19
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-01-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-01-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-02-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-02-27
#   agenda.pdf: already extracted
# 2020-03-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-03-26
#   agenda.pdf: already extracted
# 2020-04-09
#   agenda.pdf: already extracted
# 2020-04-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-05-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-05-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-06-04
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-06-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-06-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-07-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-07-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-08-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-08-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-09-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-09-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-09-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-10-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-10-15
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-10-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-11-05
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-11-19
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-12-03
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-12-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2020-12-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-01-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-01-21
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-01-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-02-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-02-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-02-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-03-04
#   agenda.pdf: already extracted
# 2021-03-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-03-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-03-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-04-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-04-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-05-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-05-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-06-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-06-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-06-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2021-07-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-07-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-08-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-08-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-09-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-09-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-09-30
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-10-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-10-21
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-10-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-11-04
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-11-18
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-12-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2021-12-16
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-01-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-01-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-02-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-02-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-03-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-03-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-03-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-04-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-04-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-05-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-05-19
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-05-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-06-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-06-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-07-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-07-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-08-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-08-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-09-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-09-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-09-29
#   agenda.pdf: already extracted
# 2022-10-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-10-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-11-03
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-11-17
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-12-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2022-12-15
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-01-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
# 2023-01-26
#   agenda.pdf: already extracted
# 2023-02-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-02-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-03-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-03-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-04-13
#   agenda.pdf: already extracted
# 2023-04-20
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-04-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-05-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-05-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-06-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-06-22
#   agenda.pdf: already extracted
# 2023-07-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-07-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-08-10
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-08-24
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-09-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-09-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-10-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-10-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-11-02
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-11-16
#   agenda-override.pdf: already extracted
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2023-12-07
#   agenda.pdf: already extracted
# 2023-12-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-01-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-01-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-02-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-02-22
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-03-14
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-03-28
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-04-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-04-25
#   agenda.pdf: already extracted
# 2024-05-09
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-05-23
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-06-13
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-06-27
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-07-11
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-07-25
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-08-08
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-08-22
#   agenda.pdf: already extracted
# 2024-09-12
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: already extracted
# 2024-09-26
#   agenda.pdf: already extracted
#   audio.pdf: already extracted
#   minutes.pdf: already extracted
#   supplemental-docs.pdf: 100... 200... 300... 400... 500... 600... 700... 800... 900... 1000... 1100... 1200... 1300... 1348 pages extracted.
# 2024-10-10
#   agenda.pdf: 6 pages extracted.
#   audio.pdf: 5 pages extracted.
#   minutes.pdf: 5 pages extracted.
#   supplemental-docs.pdf: 28 pages extracted.
# 2024-10-24
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 7 pages extracted.
#   minutes.pdf: 7 pages extracted.
#   supplemental-docs.pdf: 83 pages extracted.
# 2024-11-14
#   agenda.pdf: 9 pages extracted.
#   audio.pdf: 9 pages extracted.
#   minutes.pdf: 9 pages extracted.
#   supplemental-docs.pdf: 47 pages extracted.
# 2024-11-21
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 7 pages extracted.
#   minutes.pdf: 7 pages extracted.
#   supplemental-docs.pdf: 34 pages extracted.
# 2024-12-12
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 8 pages extracted.
#   minutes.pdf: 8 pages extracted.
#   supplemental-docs.pdf: 15 pages extracted.
# 2024-12-19
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 6 pages extracted.
#   minutes.pdf: 7 pages extracted.
#   supplemental-docs.pdf: 6 pages extracted.
# 2025-01-09
#   agenda.pdf: 10 pages extracted.
# 2025-01-23
#   agenda.pdf: 11 pages extracted.
#   audio.pdf: 10 pages extracted.
#   supplemental-docs.pdf: 55 pages extracted.
# 2025-02-13
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 8 pages extracted.
#   supplemental-docs.pdf: 27 pages extracted.
# 2025-02-27
#   agenda.pdf: 6 pages extracted.
#   audio.pdf: 5 pages extracted.
#   supplemental-docs.pdf: 91 pages extracted.
# 2025-03-13
#   agenda.pdf: 7 pages extracted.
#   audio.pdf: 6 pages extracted.
#   supplemental-docs.pdf: 100... 200... 300... 400... 500... 600... 700... 800... 845 pages extracted.
# 2025-03-27
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 7 pages extracted.
#   supplemental-docs.pdf: 93 pages extracted.
# 2025-04-10
#   agenda.pdf: 10 pages extracted.
#   audio.pdf: 8 pages extracted.
#   supplemental-docs.pdf: 88 pages extracted.
# 2025-04-24
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 7 pages extracted.
#   supplemental-docs.pdf: 100... 200... 300... 397 pages extracted.
# 2025-05-08
#   agenda.pdf: 8 pages extracted.
#   audio.pdf: 7 pages extracted.
#   supplemental-docs.pdf: 92 pages extracted.
# 2025-05-22
#   agenda.pdf: 6 pages extracted.
#   audio.pdf: 5 pages extracted.
#   supplemental-docs.pdf: 80 pages extracted.
# 2025-06-12
#   agenda.pdf: 8 pages extracted.
#   supplemental-docs.pdf: 61 pages extracted.
# Elapsed time = 21.416844828923544 mintues

# %%
os.path.join(DATA_DIR, str(year))
# Out:
# 'C:\\Users\\edwar\\projects\\lur-lm\\raw_data\\cpc\\2025'

# %%
meta_df = pd.DataFrame.from_dict(meta_df)
meta_df.to_csv(os.path.join(LOCAL_PATH, "intermediate_data/cpc/metadata.csv"), header=True, index=False)

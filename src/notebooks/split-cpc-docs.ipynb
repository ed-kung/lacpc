# %% [markdown]
# Order of operations:
#
# - extract-cpc-docs.ipynb
# - split-cpc-docs.ipynb

# %%
import os
import sys
import re
import time
from pathlib import Path
import pdfplumber
import pytesseract
from pdf2image import convert_from_path
import warnings
import logging
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

sys.path.append('../python')
warnings.filterwarnings('default')
logging.getLogger("pdfminer").setLevel(logging.ERROR)

DATA_DIR = Path('../../intermediate_data/cpc')

# %%
splits_df = pd.read_csv("../../raw_data/cpc/cpc-supplemental-docs-splits.csv")
splits_df = splits_df.fillna('')
splits_dict = {}
for idx, row in splits_df.iterrows():
    date = row['date']
    start = row['start']
    end = row['end']
    notes = row['notes']
    splits_dict[(date, start)] = (end, notes)

# %%
def extract_contents(date):
    year = date[0:4]
    filename = f"../../intermediate_data/cpc/{year}/{date}/supplemental-docs.txt"
    with open(filename, 'r') as f:
        text = f.read()
    pages = text.split("<PAGE BREAK>")
    n_pages = len(pages)
    df = []
    curr_page=1
    doc_id = 0
    while (curr_page<=n_pages):
        if splits_dict.get((date, curr_page)):
            start_page = curr_page
            end_page, notes = splits_dict.get((date, curr_page))
            if not notes:
                content = "<PAGE BREAK>".join(pages[(start_page-1):(end_page)])
            else:
                content = f"SKIPPED ({notes})"
        else:
            start_page = curr_page
            end_page = curr_page
            content = pages[start_page-1]
        df.append({
            'year': year,
            'date': date,
            'doc_id': doc_id,
            'start_page': start_page,
            'end_page': end_page,
            'content': content
        })
        doc_id+=1
        curr_page = end_page+1
    df = pd.DataFrame.from_dict(df)
    print(f"{len(df)} documents extracted")
    return df

# %%
t0 = time.time()
years = sorted([d.name for d in DATA_DIR.iterdir() if d.is_dir()])
for year in years:
    path = Path(f'../../intermediate_data/cpc/{year}')
    dates = sorted([d.name for d in path.iterdir() if d.is_dir()])
    for date in dates:
        path = Path(f'../../intermediate_data/cpc/{year}/{date}')
        files = [f.name for f in path.iterdir()]
        if 'supplemental-docs.txt' in files:
            print(date)
            df = extract_contents(date)
            df.to_pickle(f"../../intermediate_data/cpc/{year}/{date}/supplemental-docs.pkl")
t1 = time.time()
print(f"Elapsed time = {(t1-t0)/60} mintues")
# Out:
# 2018-05-10
# 26 documents extracted
# 2018-05-23
# 10 documents extracted
# 2018-06-14
# 23 documents extracted
# 2018-07-12
# 26 documents extracted
# 2018-07-26
# 42 documents extracted
# 2018-08-09
# 39 documents extracted
# 2018-08-23
# 6 documents extracted
# 2018-09-13
# 79 documents extracted
# 2018-09-27
# 13 documents extracted
# 2018-10-11
# 67 documents extracted
# 2018-10-25
# 53 documents extracted
# 2018-11-08
# 10 documents extracted
# 2018-11-29
# 16 documents extracted
# 2018-12-13
# 21 documents extracted
# 2018-12-20
# 10 documents extracted
# 2019-01-10
# 18 documents extracted
# 2019-01-24
# 40 documents extracted
# 2019-02-14
# 12 documents extracted
# 2019-02-28
# 5 documents extracted
# 2019-03-14
# 16 documents extracted
# 2019-03-28
# 22 documents extracted
# 2019-04-11
# 25 documents extracted
# 2019-05-09
# 25 documents extracted
# 2019-05-23
# 112 documents extracted
# 2019-06-13
# 5 documents extracted
# 2019-06-27
# 15 documents extracted
# 2019-07-11
# 70 documents extracted
# 2019-07-25
# 58 documents extracted
# 2019-08-08
# 79 documents extracted
# 2019-08-22
# 7 documents extracted
# 2019-09-12
# 11 documents extracted
# 2019-09-26
# 10 documents extracted
# 2019-10-10
# 28 documents extracted
# 2019-10-24
# 28 documents extracted
# 2019-11-14
# 16 documents extracted
# 2019-11-21
# 16 documents extracted
# 2019-12-12
# 40 documents extracted
# 2019-12-19
# 22 documents extracted
# 2020-01-09
# 11 documents extracted
# 2020-01-23
# 9 documents extracted
# 2020-02-13
# 17 documents extracted
# 2020-03-12
# 21 documents extracted
# 2020-04-23
# 74 documents extracted
# 2020-05-14
# 111 documents extracted
# 2020-05-28
# 188 documents extracted
# 2020-06-04
# 7 documents extracted
# 2020-06-11
# 12 documents extracted
# 2020-06-25
# 93 documents extracted
# 2020-07-09
# 9 documents extracted
# 2020-07-23
# 18 documents extracted
# 2020-08-13
# 161 documents extracted
# 2020-08-27
# 54 documents extracted
# 2020-09-10
# 12 documents extracted
# 2020-09-17
# 17 documents extracted
# 2020-09-24
# 15 documents extracted
# 2020-10-08
# 189 documents extracted
# 2020-10-15
# 25 documents extracted
# 2020-10-22
# 25 documents extracted
# 2020-11-05
# 51 documents extracted
# 2020-11-19
# 42 documents extracted
# 2020-12-03
# 20 documents extracted
# 2020-12-10
# 18 documents extracted
# 2020-12-17
# 13 documents extracted
# 2021-01-14
# 12 documents extracted
# 2021-01-21
# 4 documents extracted
# 2021-01-28
# 10 documents extracted
# 2021-02-11
# 6 documents extracted
# 2021-02-18
# 103 documents extracted
# 2021-02-25
# 49 documents extracted
# 2021-03-11
# 22 documents extracted
# 2021-03-18
# 140 documents extracted
# 2021-03-25
# 19 documents extracted
# 2021-04-08
# 11 documents extracted
# 2021-04-22
# 5 documents extracted
# 2021-05-13
# 30 documents extracted
# 2021-05-27
# 126 documents extracted
# 2021-06-10
# 45 documents extracted
# 2021-06-17
# 98 documents extracted
# 2021-07-08
# 10 documents extracted
# 2021-07-22
# 7 documents extracted
# 2021-08-12
# 5 documents extracted
# 2021-08-26
# 21 documents extracted
# 2021-09-09
# 35 documents extracted
# 2021-09-23
# 5 documents extracted
# 2021-09-30
# 5 documents extracted
# 2021-10-14
# 40 documents extracted
# 2021-10-21
# 25 documents extracted
# 2021-10-28
# 13 documents extracted
# 2021-11-04
# 29 documents extracted
# 2021-11-18
# 119 documents extracted
# 2021-12-09
# 7 documents extracted
# 2021-12-16
# 49 documents extracted
# 2022-01-13
# 35 documents extracted
# 2022-01-27
# 46 documents extracted
# 2022-02-10
# 10 documents extracted
# 2022-02-24
# 22 documents extracted
# 2022-03-10
# 25 documents extracted
# 2022-03-17
# 4 documents extracted
# 2022-03-24
# 28 documents extracted
# 2022-04-14
# 13 documents extracted
# 2022-04-28
# 171 documents extracted
# 2022-05-12
# 29 documents extracted
# 2022-05-19
# 15 documents extracted
# 2022-05-26
# 5 documents extracted
# 2022-06-09
# 25 documents extracted
# 2022-06-23
# 46 documents extracted
# 2022-07-14
# 63 documents extracted
# 2022-07-28
# 84 documents extracted
# 2022-08-11
# 15 documents extracted
# 2022-08-25
# 9 documents extracted
# 2022-09-08
# 11 documents extracted
# 2022-09-22
# 84 documents extracted
# 2022-10-13
# 19 documents extracted
# 2022-10-27
# 34 documents extracted
# 2022-11-03
# 52 documents extracted
# 2022-11-17
# 271 documents extracted
# 2022-12-08
# 128 documents extracted
# 2022-12-15
# 26 documents extracted
# 2023-02-09
# 47 documents extracted
# 2023-02-23
# 29 documents extracted
# 2023-03-09
# 26 documents extracted
# 2023-03-23
# 16 documents extracted
# 2023-04-20
# 23 documents extracted
# 2023-04-27
# 39 documents extracted
# 2023-05-11
# 14 documents extracted
# 2023-05-25
# 22 documents extracted
# 2023-06-08
# 203 documents extracted
# 2023-07-13
# 31 documents extracted
# 2023-07-27
# 36 documents extracted
# 2023-08-10
# 15 documents extracted
# 2023-08-24
# 161 documents extracted
# 2023-09-14
# 66 documents extracted
# 2023-09-28
# 29 documents extracted
# 2023-10-12
# 38 documents extracted
# 2023-10-26
# 22 documents extracted
# 2023-11-02
# 5 documents extracted
# 2023-11-16
# 18 documents extracted
# 2023-12-14
# 24 documents extracted
# 2024-01-11
# 57 documents extracted
# 2024-01-25
# 8 documents extracted
# 2024-02-08
# 61 documents extracted
# 2024-02-22
# 41 documents extracted
# 2024-03-14
# 1 documents extracted
# 2024-03-28
# 9 documents extracted
# 2024-04-11
# 35 documents extracted
# 2024-05-09
# 43 documents extracted
# 2024-05-23
# 9 documents extracted
# 2024-06-13
# 9 documents extracted
# 2024-06-27
# 11 documents extracted
# 2024-07-11
# 15 documents extracted
# 2024-07-25
# 12 documents extracted
# 2024-08-08
# 9 documents extracted
# 2024-09-12
# 25 documents extracted
# 2024-09-26
# 797 documents extracted
# 2024-10-10
# 19 documents extracted
# 2024-10-24
# 15 documents extracted
# 2024-11-14
# 18 documents extracted
# 2024-11-21
# 14 documents extracted
# 2024-12-12
# 6 documents extracted
# 2024-12-19
# 5 documents extracted
# 2025-01-23
# 30 documents extracted
# 2025-02-13
# 17 documents extracted
# 2025-02-27
# 41 documents extracted
# 2025-03-13
# 27 documents extracted
# 2025-03-27
# 18 documents extracted
# 2025-04-10
# 36 documents extracted
# Elapsed time = 0.007030697663625082 mintues

# %%
import os
import sys
import time
import yaml
import numpy as np
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By

with open('../../config.local.yaml', 'r') as f:
    local_config = yaml.safe_load(f)

LOCAL_PATH = local_config['LOCAL_PATH']
DATA_PATH = local_config['DATA_PATH']
CHROMEDRIVER = local_config['CHROMEDRIVER']

sys.path.append(os.path.join(LOCAL_PATH, "src/python"))
from scrapers import save_url_file

APCS = {
    'City Planning Commission': 'cpc'
}
FILE_LABELS = {
    3: 'agenda.pdf',
    4: 'supplemental-docs.pdf',
    5: 'audio.pdf',
    6: 'minutes.pdf'
}
YEARS = range(2026, 2002, -1)

REPLACE = False

rng = np.random.default_rng(20250611)

# %%
#--- Configure the selenium chrome driver
options = Options()
options.add_argument('--headless=new')
#service = Service(CHROMEDRIVER)
driver = webdriver.Chrome(options=options)

# %%
#--- Begin scrape

URL = 'https://planning.lacity.gov/about/commissions-boards-hearings#commissions'
driver.get(URL)
time.sleep(5) # wait for driver to be ready

for year in YEARS:
    year_select = Select(driver.find_element(By.NAME, 'date'))
    year_select.select_by_visible_text(str(year))
    time.sleep(3) # wait for dropdown data to load
    
    for apc_label, apc_dir in APCS.items():
        print(f"Downloading data for {apc_label} {year}... ")

        apc_select = Select(driver.find_element(By.NAME, 'apc'))
        apc_select.select_by_visible_text(apc_label)
        time.sleep(3) # wait for dropdown data to load


        rows = driver.find_elements(By.XPATH, "//table//tr")

        for row in rows:
            cells = row.find_elements(By.TAG_NAME, "td")
            if len(cells) < 7:
                continue

            raw_date = cells[0].text.strip()
            if not raw_date:
                continue

            hearing_date = datetime.strptime(raw_date, "%m/%d/%Y").strftime("%Y-%m-%d")
            folder_path = os.path.join(DATA_PATH, "raw_data", apc_dir, str(year), hearing_date)
            os.makedirs(folder_path, exist_ok=True)

            for index, filename in FILE_LABELS.items():
                links = cells[index].find_elements(By.TAG_NAME, "a")
                if not links:
                    continue

                link = links[0].get_attribute("href")
                if not link:
                    continue

                filepath = os.path.join(folder_path, filename)
                if os.path.exists(filepath) and not REPLACE:
                    continue
                save_url_file(link, filepath, overwrite=REPLACE, verbose=True, wait=rng.uniform(0.5,1.5))
# Out:
# Downloading data for City Planning Commission 2026...
# Downloading data for City Planning Commission 2025...
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79996...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-12-25\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79924...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-12-11\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/70378...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-12-11\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79988...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-12-11\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/80199...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-12-11\minutes.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79842...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-11-27\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79784...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-11-13\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79745...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-11-06\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/70209...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-11-06\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79808...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-11-06\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/80404...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-11-06\minutes.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79659...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-10-23\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79598...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-10-09\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/70071...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-10-09\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79658...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-10-09\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/80198...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-10-09\minutes.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79515...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-25\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/70004...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-25\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79579...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-25\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/80011...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-25\minutes.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79442...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-11\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/69934...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-11\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79495...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-11\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/80010...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-09-11\minutes.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79401...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-08-28\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79273...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-08-14\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/69779...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-08-14\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79356...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-08-14\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79787...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-08-14\minutes.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79170...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-07-24\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79090...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-07-10\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/69604...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-07-10\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79149...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-07-10\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79786...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-07-10\minutes.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79012...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-06-26\agenda.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/addtldoc/69538...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-06-26\supplemental-docs.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79078...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-06-26\audio.pdf
# Requesting https://planning.lacity.gov/dcpapi2/meetings/document/79785...
# Saved to C:/Users/edwar/Dropbox/projects/lacpc\raw_data\cpc\2025\2025-06-26\minutes.pdf
# Downloading data for City Planning Commission 2024...
# Downloading data for City Planning Commission 2023...
# Downloading data for City Planning Commission 2022...
# Downloading data for City Planning Commission 2021...
# Downloading data for City Planning Commission 2020...
# Downloading data for City Planning Commission 2019...
# Downloading data for City Planning Commission 2018...
# Downloading data for City Planning Commission 2017...
# Downloading data for City Planning Commission 2016...
# Downloading data for City Planning Commission 2015...
# Downloading data for City Planning Commission 2014...
# Downloading data for City Planning Commission 2013...
# Downloading data for City Planning Commission 2012...
# Downloading data for City Planning Commission 2011...
# Downloading data for City Planning Commission 2010...
# Downloading data for City Planning Commission 2009...
# Downloading data for City Planning Commission 2008...
# Downloading data for City Planning Commission 2007...
# Downloading data for City Planning Commission 2006...
# Downloading data for City Planning Commission 2005...
# Downloading data for City Planning Commission 2004...
# Downloading data for City Planning Commission 2003...
